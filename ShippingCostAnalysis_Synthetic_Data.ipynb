# %% [markdown]
# <a href="https://colab.research.google.com/github/Requenamar3/Projects/blob/main/ShippingCostAnalysis_Synthetic_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install faker

# %%
from datetime import timedelta
import pandas as pd
from faker import Faker
import random



# Initialize Faker
fake = Faker()

# %%
# Number of data points
num_orders = 10000  # Adjust as needed
num_routes = 300  # Adjust as needed
num_zip_codes = 1000  # Adjust this number as needed
num_transactions = 10000  # Adjust as needed

# %%
# 1. Generate Orders Table Data
orders_data = {
    'Order_ID': [f'ORD{str(i).zfill(4)}' for i in range(1, num_orders + 1)],
    'Distribution_Center_ID': [random.choice(['DC1', 'DC2', 'DC3', 'DC4', 'DC5', 'DC6']) for _ in range(num_orders)],
    'Customer_ZIP': [fake.zipcode() for _ in range(num_orders)],
    'Delivery_Type': [random.choice(['Ground', 'Air']) for _ in range(num_orders)],
    'Service_Type': [random.choice(['Ground', 'Standard Overnight', 'Priority Overnight']) for _ in range(num_orders)],
    'Cost': [round(random.uniform(10, 300), 2) for _ in range(num_orders)],
    'Event_Type': [random.choice(['Birthday', 'Holiday', 'Wedding', 'Graduation', 'Bridal Shower',
                                  'Retirement', 'Gender Reveal', 'First Communion', 'None']) for _ in range(num_orders)],
    'Holiday_Flag': [random.choice([0, 1]) for _ in range(num_orders)],
    'Carrier_Reliability_Score': None  # Placeholder for future data
}
orders_df = pd.DataFrame(orders_data)

print("Orders Table Overview:")
display(orders_df.head())
orders_df.info()
print(orders_df.describe())
# Out:
# Orders Table Overview:
#   Order_ID Distribution_Center_ID Customer_ZIP Delivery_Type  \
# 0  ORD0001                    DC4        77515           Air
# 1  ORD0002                    DC6        93362           Air
# 2  ORD0003                    DC3        09818        Ground
# 3  ORD0004                    DC1        20111           Air
# 4  ORD0005                    DC5        70972        Ground
#
#          Service_Type    Cost     Event_Type  Holiday_Flag  \
# 0              Ground  147.95           None             1
# 1  Priority Overnight  150.18     Graduation             1
# 2  Priority Overnight  129.36        Holiday             1
# 3              Ground  111.14  Gender Reveal             1
# 4  Standard Overnight  157.93        Holiday             0
#
#   Carrier_Reliability_Score
# 0                      None
# 1                      None
# 2                      None
# 3                      None
# 4                      None
# <class 'pandas.core.frame.DataFrame'>
# ...

# %%
# 2. Generate Distribution Centers Table
distribution_centers_data = {
    'Center_ID': ['DC1', 'DC2', 'DC3', 'DC4', 'DC5', 'DC6'],
    'Location': ['Los Angeles, CA', 'Miami, FL', 'Dallas, TX', 'Bronx, NY', 'Hatfield, PA', 'Chicago, IL'],
    'ZIP_Code': [fake.zipcode_in_state('CA'), fake.zipcode_in_state('FL'), fake.zipcode_in_state('TX'),
                 fake.zipcode_in_state('NY'), fake.zipcode_in_state('PA'), fake.zipcode_in_state('IL')],
    'Volume_Allocation': [0.20, 0.12, 0.10, 0.26, 0.18, 0.14]  # Updated allocations
}
distribution_centers_df = pd.DataFrame(distribution_centers_data)

print("\nDistribution Centers Table Overview:")
display(distribution_centers_df.head())
distribution_centers_df.info()
print(distribution_centers_df.describe())
# Out:
# Distribution Centers Table Overview:
#   Center_ID         Location ZIP_Code  Volume_Allocation
# 0       DC1  Los Angeles, CA    95296               0.20
# 1       DC2        Miami, FL    34780               0.12
# 2       DC3       Dallas, TX    78418               0.10
# 3       DC4        Bronx, NY    11650               0.26
# 4       DC5     Hatfield, PA    16965               0.18
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Center_ID          6 non-null      object
#  1   Location           6 non-null      object
#  2   ZIP_Code           6 non-null      object
#  3   Volume_Allocation  6 non-null      float64
# dtypes: float64(1), object(3)
# memory usage: 320.0+ bytes
#        Volume_Allocation
# count           6.000000
# mean            0.166667
# std             0.058878
# min             0.100000
# ...

# %%
# 3. Generate Carriers Table Data
carriers_data = {
    'Carrier_ID': ['C1', 'C2', 'C3', 'C4', 'C5', 'C6'],
    'Name': ['UPS Ground', 'FedEx Ground', 'OnTrac', 'FedEx Standard Overnight', 'FedEx Priority Overnight', 'UPS Air'],
    'Flat_Rate': [2.2, 2.8, 2.5, 5.0, 7.0, 6.5],  # Adjust rates as needed
    'Service_Type': ['Ground', 'Ground', 'Ground', 'Air', 'Air', 'Air']
}
carriers_df = pd.DataFrame(carriers_data)

print("\nCarriers Table Overview:")
display(carriers_df.head())
carriers_df.info()
print(carriers_df.describe())
# Out:
# Carriers Table Overview:
#   Carrier_ID                      Name  Flat_Rate Service_Type
# 0         C1                UPS Ground        2.2       Ground
# 1         C2              FedEx Ground        2.8       Ground
# 2         C3                    OnTrac        2.5       Ground
# 3         C4  FedEx Standard Overnight        5.0          Air
# 4         C5  FedEx Priority Overnight        7.0          Air
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Carrier_ID    6 non-null      object
#  1   Name          6 non-null      object
#  2   Flat_Rate     6 non-null      float64
#  3   Service_Type  6 non-null      object
# dtypes: float64(1), object(3)
# memory usage: 320.0+ bytes
#        Flat_Rate
# count   6.000000
# mean    4.333333
# std     2.121949
# min     2.200000
# 25%     2.575000
# 50%     3.900000
# 75%     6.125000
# ...

# %%
# 4.Generate the Routes_Details Table Data
routes_details_data = {
    'Route_ID': [f'R{i}' for i in range(1, num_routes + 1)],
    'Center_ID': [random.choice(['DC1', 'DC2', 'DC3', 'DC4', 'DC5', 'DC6']) for _ in range(num_routes)],
    'From_ZIP': [fake.zipcode() for _ in range(num_routes)],  # ZIP code of the facility (distribution center)
    'From_State': [fake.state_abbr() for _ in range(num_routes)],
    'To_ZIP': [fake.zipcode() for _ in range(num_routes)],  # Customer ZIP code
    'To_State': [fake.state_abbr() for _ in range(num_routes)],
    'Distance': [round(random.uniform(50, 3000), 2) for _ in range(num_routes)],  # Distance in miles
    'Preferred_Mode': [
        'Ground' if random.random() < 0.7 else 'Air'  # Randomly prefer ground over air, assuming ground is generally cheaper
        for _ in range(num_routes)
    ],
    'Carrier_ID': [
        random.choice(['C1', 'C2', 'C3', 'C4', 'C5', 'C6'])  # Carrier IDs referencing entries in the Carriers table
        for _ in range(num_routes)
    ]
}

# Create the DataFrame
routes_details_df = pd.DataFrame(routes_details_data)

# Display the sample Routes_Details Table
print("\nSample Routes_Details Table")
display(routes_details_df.head())  # Show the first 5 rows of the Routes_Details table
routes_details_df.info()           # Show data types and non-null count
print(routes_details_df.describe()) # Provides descriptive statistics for numerical columns
# Out:
# Sample Routes_Details Table
#   Route_ID Center_ID From_ZIP From_State To_ZIP To_State  Distance  \
# 0       R1       DC6    39557         AS  15273       PW   1115.62
# 1       R2       DC1    55159         HI  43702       OR    191.33
# 2       R3       DC4    64431         DE  82201       NM   2985.28
# 3       R4       DC4    33489         DC  46212       AK    169.97
# 4       R5       DC2    25396         MP  32692       SD   2401.59
#
#   Preferred_Mode Carrier_ID
# 0         Ground         C6
# 1            Air         C5
# 2            Air         C5
# 3            Air         C3
# 4            Air         C3
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Route_ID        300 non-null    object
#  1   Center_ID       300 non-null    object
#  2   From_ZIP        300 non-null    object
# ...

# %%
zip_codes_data = {
    'ZIP_Code': [fake.zipcode() for _ in range(num_zip_codes)],
    'Route_ID': [random.choice(routes_details_df['Route_ID'].tolist()) for _ in range(num_zip_codes)]
}

zip_codes_df = pd.DataFrame(zip_codes_data)

# Display the sample ZipCodes Table
print("\nSample ZipCodes Table")
display(zip_codes_df.head())  # This will show the first 5 rows of the ZipCodes table
zip_codes_df.info()           # This shows the data types and non-null count
print(zip_codes_df.describe()) # Provides descriptive statistics for numerical columns, if any
# Out:
# Sample ZipCodes Table
#   ZIP_Code Route_ID
# 0    01835     R123
# 1    87491     R210
# 2    64562      R18
# 3    99648     R100
# 4    98473     R216
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ZIP_Code  1000 non-null   object
#  1   Route_ID  1000 non-null   object
# dtypes: object(2)
# memory usage: 15.8+ KB
#        ZIP_Code Route_ID
# count      1000     1000
# unique      994      291
# top       57859      R83
# freq          2       10

# %%
# 6. Generate Shipping Transactions Table Data
shipping_transactions_data = {
    'Transaction_ID': [f'TXN{str(i).zfill(4)}' for i in range(1, num_transactions + 1)],
    'Order_ID': [random.choice(orders_df['Order_ID']) for _ in range(num_transactions)],
    'Carrier_ID': [random.choice(carriers_df['Carrier_ID']) for _ in range(num_transactions)],
    'Route_ID': [random.choice(routes_details_df['Route_ID']) for _ in range(num_transactions)],
    'Shipping_Cost': [round(random.uniform(10, 300), 2) for _ in range(num_transactions)],
    'Transaction_Date': [fake.date_this_year() for _ in range(num_transactions)]
}

# Convert the dictionary to a DataFrame
shipping_transactions_df = pd.DataFrame(shipping_transactions_data)

# Generate Scheduled Delivery Date as 1 to 5 days after the Transaction Date
shipping_transactions_df['Scheduled_Delivery_Date'] = shipping_transactions_df['Transaction_Date'] + pd.to_timedelta(
    [random.randint(1, 5) for _ in range(num_transactions)], unit='D'
)

# Set Actual Delivery Date to be the same as Scheduled Delivery Date to indicate on-time delivery
shipping_transactions_df['Actual_Delivery_Date'] = shipping_transactions_df['Scheduled_Delivery_Date']

# Generate Shipping Date as 1 to 3 days before the Scheduled Delivery Date
shipping_transactions_df['Shipping_Date'] = shipping_transactions_df['Scheduled_Delivery_Date'] - pd.to_timedelta(
    [random.randint(1, 3) for _ in range(num_transactions)], unit='D'
)

# Display the updated table with the new columns
print("\nUpdated Shipping Transactions Table with Shipping and Delivery Dates")
display(shipping_transactions_df.head())  # Shows the first 5 rows
shipping_transactions_df.info()           # Displays data types and non-null count
print(shipping_transactions_df.describe()) # Provides descriptive statistics for numerical columns, if any
# Out:
# Updated Shipping Transactions Table with Shipping and Delivery Dates
# <ipython-input-28-5b3470ab3e90>:15: PerformanceWarning: Adding/subtracting object-dtype array to TimedeltaArray not vectorized.
#   shipping_transactions_df['Scheduled_Delivery_Date'] = shipping_transactions_df['Transaction_Date'] + pd.to_timedelta(
# <ipython-input-28-5b3470ab3e90>:23: PerformanceWarning: Adding/subtracting object-dtype array to TimedeltaArray not vectorized.
#   shipping_transactions_df['Shipping_Date'] = shipping_transactions_df['Scheduled_Delivery_Date'] - pd.to_timedelta(
#   Transaction_ID Order_ID Carrier_ID Route_ID  Shipping_Cost Transaction_Date  \
# 0        TXN0001  ORD3570         C2     R140         151.36       2024-05-28
# 1        TXN0002  ORD1311         C1       R3          32.72       2024-07-14
# 2        TXN0003  ORD0248         C6      R89          97.03       2024-02-03
# 3        TXN0004  ORD4048         C6      R66         120.71       2024-03-02
# ...

# %%
# Export each DataFrame to CSV
orders_df.to_csv('Orders.csv', index=False)
distribution_centers_df.to_csv('Distribution_Centers.csv', index=False)
carriers_df.to_csv('Carriers.csv', index=False)
routes_details_df.to_csv('Routes_Details.csv', index=False)
zip_codes_df.to_csv('Zip_Codes.csv', index=False)
shipping_transactions_df.to_csv('Shipping_Transactions.csv', index=False)

# %%
from google.colab import files

# Download each CSV file
files.download('Orders.csv')
files.download('Distribution_Centers.csv')
files.download('Carriers.csv')
files.download('Routes_Details.csv')
files.download('Zip_Codes.csv')
files.download('Shipping_Transactions.csv')
